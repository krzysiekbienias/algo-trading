# %% [markdown]
# # 00 — Setup smoke test
#
# Verify `quant_sandbox` imports and load one symbol from the local data lake.
# Kernel: **Algo Trading (quant_sandbox)**.

# %%
import os

from quant_sandbox import find_repo_root, load_bars

print("repo:", find_repo_root())
print("QUANT_DATA_LAKE:", os.environ.get("QUANT_DATA_LAKE", "(default data_lake_m1)"))

# %%
SYMBOL = "NVDA"
START = "2024-05-01"

df = load_bars(SYMBOL, start=START)
print("bars:", len(df))
print("from:", df.index.min(), "to:", df.index.max())
df.head()
